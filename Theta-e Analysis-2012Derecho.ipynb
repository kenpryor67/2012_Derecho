# %% [markdown]
# ## June 2012 Derecho Theta-e Analysis 1700 UTC 29 June 2012

# %%
from __future__ import print_function, division
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import matplotlib.cm as cm
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.io.shapereader as shpreader

# %%
def read_RAP_T(ncf):
    nc_fid = Dataset(ncf, 'r')
    Y = 185
    Xmin = 270
    Xmax = 310
    T_1000 = pd.Series(nc_fid.variables["Band38"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_975 = pd.Series(nc_fid.variables["Band39"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_950 = pd.Series(nc_fid.variables["Band40"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_925 = pd.Series(nc_fid.variables["Band41"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_900 = pd.Series(nc_fid.variables["Band42"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_875 = pd.Series(nc_fid.variables["Band43"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_850 = pd.Series(nc_fid.variables["Band44"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_825 = pd.Series(nc_fid.variables["Band45"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_800 = pd.Series(nc_fid.variables["Band46"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_775 = pd.Series(nc_fid.variables["Band47"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_750 = pd.Series(nc_fid.variables["Band48"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_725 = pd.Series(nc_fid.variables["Band49"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_700 = pd.Series(nc_fid.variables["Band50"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_675 = pd.Series(nc_fid.variables["Band51"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_650 = pd.Series(nc_fid.variables["Band52"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_625 = pd.Series(nc_fid.variables["Band53"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_600 = pd.Series(nc_fid.variables["Band54"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_575 = pd.Series(nc_fid.variables["Band55"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_550 = pd.Series(nc_fid.variables["Band56"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_525 = pd.Series(nc_fid.variables["Band57"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_500 = pd.Series(nc_fid.variables["Band58"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_475 = pd.Series(nc_fid.variables["Band59"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_450 = pd.Series(nc_fid.variables["Band60"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_425 = pd.Series(nc_fid.variables["Band61"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_400 = pd.Series(nc_fid.variables["Band62"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_375 = pd.Series(nc_fid.variables["Band63"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_350 = pd.Series(nc_fid.variables["Band64"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_325 = pd.Series(nc_fid.variables["Band65"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_300 = pd.Series(nc_fid.variables["Band66"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_275 = pd.Series(nc_fid.variables["Band67"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_250 = pd.Series(nc_fid.variables["Band68"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_225 = pd.Series(nc_fid.variables["Band69"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    T_200 = pd.Series(nc_fid.variables["Band70"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    x = nc_fid.variables['x'][:]
    T_RAP = pd.DataFrame({'T_1000':T_1000, 'T_975':T_975, 'T_950':T_950, 'T_925':T_925, 'T_900':T_900, 
                          'T_875':T_875, 'T_850':T_850, 'T_825':T_825, 'T_800':T_800, 
                          'T_775':T_775, 'T_750':T_750, 'T_725':T_725, 'T_700':T_700,
                          'T_675':T_675, 'T_650':T_650, 'T_625':T_625, 'T_600':T_600, 
                          'T_575':T_575, 'T_550':T_550, 'T_525':T_525, 'T_500':T_500, 
                          'T_475':T_475, 'T_450':T_450, 'T_425':T_425, 'T_400':T_400, 
                          'T_375':T_375, 'T_350':T_350, 'T_325':T_325, 'T_300':T_300, 
                          'T_275':T_275, 'T_250':T_250, 'T_225':T_225, 'T_200':T_200})
    nc_fid.close()
    return x, T_RAP

def read_RAP_RH(ncf):
    nc_fid = Dataset(ncf, 'r')
    Y = 185
    Xmin = 270
    Xmax = 310
    RH_1000 = pd.Series(nc_fid.variables["Band75"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_975 = pd.Series(nc_fid.variables["Band76"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_950 = pd.Series(nc_fid.variables["Band77"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_925 = pd.Series(nc_fid.variables["Band78"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_900 = pd.Series(nc_fid.variables["Band79"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_875 = pd.Series(nc_fid.variables["Band80"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_850 = pd.Series(nc_fid.variables["Band81"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_825 = pd.Series(nc_fid.variables["Band82"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_800 = pd.Series(nc_fid.variables["Band83"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_775 = pd.Series(nc_fid.variables["Band84"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_750 = pd.Series(nc_fid.variables["Band85"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_725 = pd.Series(nc_fid.variables["Band86"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_700 = pd.Series(nc_fid.variables["Band87"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_675 = pd.Series(nc_fid.variables["Band88"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_650 = pd.Series(nc_fid.variables["Band89"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_625 = pd.Series(nc_fid.variables["Band90"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_600 = pd.Series(nc_fid.variables["Band91"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_575 = pd.Series(nc_fid.variables["Band92"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_550 = pd.Series(nc_fid.variables["Band93"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_525 = pd.Series(nc_fid.variables["Band94"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_500 = pd.Series(nc_fid.variables["Band95"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_475 = pd.Series(nc_fid.variables["Band96"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_450 = pd.Series(nc_fid.variables["Band97"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_425 = pd.Series(nc_fid.variables["Band98"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_400 = pd.Series(nc_fid.variables["Band99"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_375 = pd.Series(nc_fid.variables["Band100"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_350 = pd.Series(nc_fid.variables["Band101"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_325 = pd.Series(nc_fid.variables["Band102"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_300 = pd.Series(nc_fid.variables["Band103"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_275 = pd.Series(nc_fid.variables["Band104"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_250 = pd.Series(nc_fid.variables["Band105"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_225 = pd.Series(nc_fid.variables["Band106"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    RH_200 = pd.Series(nc_fid.variables["Band107"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    x = nc_fid.variables['x'][:]
    RH_RAP = pd.DataFrame({'RH_1000':RH_1000, 'RH_975':RH_975, 'RH_950':RH_950, 'RH_925':RH_925, 'RH_900':RH_900, 
                           'RH_875':RH_875, 'RH_850':RH_850, 'RH_825':RH_825, 'RH_800':RH_800, 
                           'RH_775':RH_775, 'RH_750':RH_750, 'RH_725':RH_725, 'RH_700':RH_700,
                           'RH_675':RH_675, 'RH_650':RH_650, 'RH_625':RH_625, 'RH_600':RH_600, 
                           'RH_575':RH_575, 'RH_550':RH_550, 'RH_525':RH_525, 'RH_500':RH_500, 
                           'RH_475':RH_475, 'RH_450':RH_450, 'RH_425':RH_425, 'RH_400':RH_400,
                           'RH_375':RH_375, 'RH_350':RH_350, 'RH_325':RH_325, 'RH_300':RH_300, 
                           'RH_275':RH_275, 'RH_250':RH_250, 'RH_225':RH_225, 'RH_200':RH_200})
    nc_fid.close()
    return x, RH_RAP

def read_RAP_VV(ncf):
    nc_fid = Dataset(ncf, 'r')
    Y = 185
    Xmin = 270
    Xmax = 310
    VV_1000 = pd.Series(nc_fid.variables["Band186"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_975 = pd.Series(nc_fid.variables["Band187"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_950 = pd.Series(nc_fid.variables["Band188"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_925 = pd.Series(nc_fid.variables["Band189"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_900 = pd.Series(nc_fid.variables["Band190"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_875 = pd.Series(nc_fid.variables["Band191"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_850 = pd.Series(nc_fid.variables["Band192"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_825 = pd.Series(nc_fid.variables["Band193"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_800 = pd.Series(nc_fid.variables["Band194"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_775 = pd.Series(nc_fid.variables["Band195"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_750 = pd.Series(nc_fid.variables["Band196"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_725 = pd.Series(nc_fid.variables["Band197"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_700 = pd.Series(nc_fid.variables["Band198"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_675 = pd.Series(nc_fid.variables["Band199"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_650 = pd.Series(nc_fid.variables["Band200"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_625 = pd.Series(nc_fid.variables["Band201"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_600 = pd.Series(nc_fid.variables["Band202"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_575 = pd.Series(nc_fid.variables["Band203"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_550 = pd.Series(nc_fid.variables["Band204"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_525 = pd.Series(nc_fid.variables["Band205"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_500 = pd.Series(nc_fid.variables["Band206"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_475 = pd.Series(nc_fid.variables["Band207"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_450 = pd.Series(nc_fid.variables["Band208"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_425 = pd.Series(nc_fid.variables["Band209"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_400 = pd.Series(nc_fid.variables["Band210"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_375 = pd.Series(nc_fid.variables["Band211"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_350 = pd.Series(nc_fid.variables["Band212"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_325 = pd.Series(nc_fid.variables["Band213"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_300 = pd.Series(nc_fid.variables["Band214"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_275 = pd.Series(nc_fid.variables["Band215"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_250 = pd.Series(nc_fid.variables["Band216"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    VV_225 = pd.Series(nc_fid.variables["Band217"][Y,Xmin:Xmax].tolist())  
    VV_200 = pd.Series(nc_fid.variables["Band218"][Y,Xmin:Xmax].tolist())  # shape lat, lon as shown above
    x = nc_fid.variables['x'][:]
    VV_RAP = pd.DataFrame({'VV_1000':VV_1000, 'VV_975':VV_975, 'VV_950':VV_950, 'VV_925':VV_925, 'VV_900':VV_900,
                           'VV_875':VV_875, 'VV_850':VV_850, 'VV_825':VV_825, 'VV_800':VV_800, 
                           'VV_775':VV_775, 'VV_750':VV_750, 'VV_725':VV_725, 'VV_700':VV_700,
                           'VV_675':VV_675, 'VV_650':VV_650, 'VV_625':VV_625, 'VV_600':VV_600, 
                           'VV_575':VV_575, 'VV_550':VV_550, 'VV_525':VV_525, 'VV_500':VV_500, 
                           'VV_475':VV_475, 'VV_450':VV_450, 'VV_425':VV_425, 'VV_400':VV_400,
                           'VV_375':VV_375, 'VV_350':VV_350, 'VV_325':VV_325, 'VV_300':VV_300, 
                           'VV_275':VV_275, 'VV_250':VV_250, 'VV_225':VV_225, 'VV_200':VV_200})
    nc_fid.close()
    return x, VV_RAP

RAP_file = 'rap_130_20120629_1700_000.nc'
x,T = read_RAP_T(RAP_file)
T = T.loc[:,['T_1000', 'T_975', 'T_950', 'T_925', 'T_900', 'T_875', 'T_850', 'T_825', 'T_800', 
             'T_775', 'T_750', 'T_725', 'T_700', 'T_675', 'T_650', 'T_625', 'T_600', 
             'T_575', 'T_550', 'T_525', 'T_500', 'T_475', 'T_450', 'T_425', 'T_400', 
             'T_375', 'T_350', 'T_325', 'T_300', 'T_275', 'T_250', 'T_225', 'T_200']]
TT = T.T
print("T = ", TT)
plt.figure()
T.plot(y=["T_1000", "T_975", "T_950", "T_925", "T_900"])
T_np = TT.to_numpy()
print("T array = ", T_np, T_np.shape)
T_npK = T_np + 273.15
print("T array K = ", T_npK, T_npK.shape)

x,RH = read_RAP_RH(RAP_file)
RH = RH.loc[:,['RH_1000', 'RH_975', 'RH_950', 'RH_925', 'RH_900', 'RH_875', 'RH_850', 'RH_825', 'RH_800', 
             'RH_775', 'RH_750', 'RH_725', 'RH_700', 'RH_675', 'RH_650', 'RH_625', 'RH_600', 
             'RH_575', 'RH_550', 'RH_525', 'RH_500', 'RH_475', 'RH_450', 'RH_425', 'RH_400', 
             'RH_375', 'RH_350', 'RH_325', 'RH_300', 'RH_275', 'RH_250', 'RH_225', 'RH_200']]
RHT = RH.T
print("RH = ", RHT)
plt.figure()
RH.plot(y=["RH_1000", "RH_975", "RH_950", "RH_925", "RH_900"])
RH_np = RHT.to_numpy()
print("RH array = ", RH_np, RH_np.shape)

x,VV = read_RAP_VV(RAP_file)
VV = VV.loc[:,['VV_1000', 'VV_975', 'VV_950', 'VV_925', 'VV_900', 'VV_875', 'VV_850', 'VV_825', 'VV_800', 
             'VV_775', 'VV_750', 'VV_725', 'VV_700', 'VV_675', 'VV_650', 'VV_625', 'VV_600', 
             'VV_575', 'VV_550', 'VV_525', 'VV_500', 'VV_475', 'VV_450', 'VV_425', 'VV_400', 
             'VV_375', 'VV_350', 'VV_325', 'VV_300', 'VV_275', 'VV_250', 'VV_225', 'VV_200']]
VVT = VV.T
print("VV = ", VVT)
plt.figure()
VV.plot(y=["VV_1000", "VV_975", "VV_950", "VV_925", "VV_900"])
VV_np = VVT.to_numpy()
print("VV array = ", VV_np, VV_np.shape)
# Out:
# T =                 0          1          2          3          4          5   \
# T_1000  25.147607  24.772607  24.522607  24.397607  24.272607  24.147607
# T_975   23.827295  23.452295  23.327295  23.202295  23.327295  23.452295
# T_950   22.781885  22.531885  22.406885  22.406885  22.531885  22.531885
# T_925   21.367578  21.117578  20.992578  20.992578  20.992578  20.992578
# T_900   21.331689  21.081689  20.831689  20.581689  20.331689  20.206689
# T_875   21.982813  21.857813  21.482813  21.107813  20.732813  20.232813
# T_850   22.189600  22.064600  21.814600  21.439600  21.064600  20.689600
# T_825   21.722070  21.597070  21.472070  21.222070  21.097070  20.972070
# T_800   20.672510  20.547510  20.422510  20.422510  20.422510  20.547510
# T_775   19.046533  18.921533  18.921533  18.921533  19.046533  19.171533
# T_750   16.763330  16.638330  16.513330  16.513330  16.513330  16.513330
# T_725   14.295068  14.045068  13.920068  13.795068  13.795068  13.670068
# ...

# %%
"""
Plot vertical temperature cross section
"""
press = np.array([1000, 975, 950, 925, 900, 875, 850, 825, 800, 775, 750, 725, 700, 675, 650, 625, 600, 
                  575, 550, 525, 500, 475, 450, 425, 400, 375, 350, 325, 300, 275, 250, 225, 200])
print(len(press))
X = np.arange(270,310,1)
X_pos, prlevs = np.meshgrid(X, press)
print("X_pos: ", X_pos, X_pos.shape)
print("Pr levels: ", prlevs, prlevs.shape)
T_min = np.amin(T_np)
T_max = np.amax(T_np)

print("T min, T max = %f K %f K" % (T_min, T_max))
levels_T = np.arange(-55,35,2)

fig = plt.figure(figsize=(12,12))
cf = plt.contourf(X_pos, prlevs, T_np, cmap=cm.jet, levels = levels_T)
plt.ylim(1000,200)
plt.colorbar(cf)

plt.plot(298, 995,'w^',markersize=9)
plt.text(298, 985, 'MCY', color='white', weight='bold')
plt.xlabel("X Position")
plt.ylabel("Height (mb)")
plt.title("Temperature (C) 1700 UTC 29 June 2012")
plt.savefig("temp_crosssctn_1700.png",dpi=250,bbox_inches='tight')
plt.grid(True)
plt.show()
# Out:
# 33
# X_pos:  [[270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  ...
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]] (33, 40)
# Pr levels:  [[1000 1000 1000 ... 1000 1000 1000]
#  [ 975  975  975 ...  975  975  975]
#  [ 950  950  950 ...  950  950  950]
#  ...
#  [ 250  250  250 ...  250  250  250]
#  [ 225  225  225 ...  225  225  225]
#  [ 200  200  200 ...  200  200  200]] (33, 40)
# T min, T max = -55.779059 K 32.147607 K

# %%
"""
Plot vertical theta cross section
"""
press = np.array([1000, 975, 950, 925, 900, 875, 850, 825, 800, 775, 750, 725, 700, 675, 650, 625, 600, 
                  575, 550, 525, 500, 475, 450, 425, 400, 375, 350, 325, 300, 275, 250, 225, 200])
print(len(press))
X = np.arange(270,310,1)
X_pos, prlevs = np.meshgrid(X, press)
print("X_pos: ", X_pos, X_pos.shape)
print("Pr levels: ", prlevs, prlevs.shape)
Theta = T_npK*((1000/prlevs)**0.286)
TH_min = np.amin(Theta)
TH_max = np.amax(Theta)
RH_min = np.amin(RH_np)
RH_max = np.amax(RH_np)
VV_min = np.amin(VV_np)
VV_max = np.amax(VV_np)
print("Theta min, Theta max = %f K %f K" % (TH_min, TH_max))
print("RH min, RH max = %f %f" % (RH_min, RH_max))
print("VV min, VV max = %f Pa/s %f Pa/s" % (VV_min, VV_max))
levels_TH = np.arange(290,360,2.5)
levels_RH = np.array([86,88,90,92,94,96,98])
levels_VV = np.arange(-2.0,4.0,0.25)

fig = plt.figure(figsize=(12,12))
cf = plt.contourf(X_pos, prlevs, Theta, cmap=cm.jet, levels = levels_TH)
CS = plt.contour(X_pos, prlevs, VV_np, colors='w', levels = levels_VV)
plt.clabel(CS, inline=True, inline_spacing = 1, fontsize=10, fmt='%1.0f')
plt.ylim(1000,200)
plt.colorbar(cf)

plt.plot(298, 995,'w^',markersize=9)
plt.text(298, 985, 'MCY', color='white', weight='bold')
plt.xlabel("X Position")
plt.ylabel("Height (mb)")
plt.title("Theta (K) and Vertical Velocity (Pa/s) 1700 UTC 29 June 2012")
plt.savefig("thta_crosssctn_1700.png",dpi=250,bbox_inches='tight')
plt.grid(True)
plt.show()
# Out:
# 33
# X_pos:  [[270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  ...
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]] (33, 40)
# Pr levels:  [[1000 1000 1000 ... 1000 1000 1000]
#  [ 975  975  975 ...  975  975  975]
#  [ 950  950  950 ...  950  950  950]
#  ...
#  [ 250  250  250 ...  250  250  250]
#  [ 225  225  225 ...  225  225  225]
#  [ 200  200  200 ...  200  200  200]] (33, 40)
# Theta min, Theta max = 293.922607 K 350.178694 K
# RH min, RH max = 3.000000 100.000000
# VV min, VV max = -1.966438 Pa/s 3.877988 Pa/s

# %%
"""
Plot vertical theta-e cross section
"""

press = np.array([1000, 975, 950, 925, 900, 875, 850, 825, 800, 775, 750, 725, 700, 675, 650, 625, 600, 
                  575, 550, 525, 500, 475, 450, 425, 400, 375, 350, 325, 300, 275, 250, 225, 200])
print(len(press))
X = np.arange(270,310,1)
X_pos, prlevs = np.meshgrid(X, press)
print("X_pos: ", X_pos, X_pos.shape)
print("Pr levels: ", prlevs, prlevs.shape)

ThetaE = (273.15 + T_np)*((1000/prlevs)**0.286)+(3 * (RH_np * (3.884266 * 10**
         ((7.5 * T_np)/(237.7 + T_np)))/100))
THe_min = np.amin(ThetaE)
THe_max = np.amax(ThetaE)
THe_mean = np.mean(ThetaE)
print("Thetae min, Thetae max, Thetae mean = %f K %f K %f K" % (THe_min, THe_max, THe_mean))
THe_dev = ThetaE - THe_mean
THe_dev_min = np.amin(THe_dev)
THe_dev_max = np.amax(THe_dev)
print("Dev min, Dev max = %f K %f K" % (THe_dev_min, THe_dev_max))
levels_TE = np.arange(300,355,2.5)
levels_RH = np.array([86,88,90,92,94,96,98])
levels_VV = np.arange(-2.0,4.0,0.25)
levels_Dev = np.arange(-23,20,0.5)

fig = plt.figure(figsize=(12,12))
cf = plt.contourf(X_pos, prlevs, ThetaE, cmap=cm.jet, levels = levels_TE)
CS = plt.contour(X_pos, prlevs, VV_np, colors='w', levels = levels_VV)
plt.clabel(CS, inline=True, inline_spacing = 1, fontsize=10, fmt='%1.0f')
plt.ylim(1000,200)
plt.colorbar(cf)

plt.plot(298, 995,'w^',markersize=9)
plt.text(298, 985, 'MCY', color='white', weight='bold')
plt.xlabel("X Position")
plt.ylabel("Height (mb)")
plt.title("Theta-E (K) and Vertical Velocity (Pa/s) 1700 UTC 29 June 2012")
plt.savefig("thtae_crosssctn_1700.png",dpi=250,bbox_inches='tight')
plt.grid(True)
plt.show()

fig = plt.figure(figsize=(12,12))
cf = plt.contourf(X_pos, prlevs, THe_dev, cmap=cm.jet, levels = levels_Dev)
CS = plt.contour(X_pos, prlevs, VV_np, colors='w', levels = levels_VV)
plt.clabel(CS, inline=True, inline_spacing = 1, fontsize=10, fmt='%1.0f')
plt.ylim(1000,200)
plt.colorbar(cf)

plt.plot(298, 995,'w^',markersize=9)
plt.text(298, 985, 'MCY', color='white', weight='bold')
plt.xlabel("X Position")
plt.ylabel("Height (mb)")
plt.title("Theta-E Deviation (K) and Vertical Velocity (Pa/s) 1700 UTC 29 June 2012")
plt.savefig("thtaedev_crosssctn_1700.png",dpi=250,bbox_inches='tight')
plt.grid(True)
plt.show()
# Out:
# 33
# X_pos:  [[270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  ...
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]
#  [270 271 272 ... 307 308 309]] (33, 40)
# Pr levels:  [[1000 1000 1000 ... 1000 1000 1000]
#  [ 975  975  975 ...  975  975  975]
#  [ 950  950  950 ...  950  950  950]
#  ...
#  [ 250  250  250 ...  250  250  250]
#  [ 225  225  225 ...  225  225  225]
#  [ 200  200  200 ...  200  200  200]] (33, 40)
# Thetae min, Thetae max, Thetae mean = 307.941163 K 350.226841 K 330.489144 K
# Dev min, Dev max = -22.547981 K 19.737697 K
